# %% [markdown]
# <a href="https://colab.research.google.com/github/The-DigitalAcademy/TrendHunt-Application/blob/Model/Image_recognition_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Specify the path to the directory you want to list
directory_path = "/content/drive/MyDrive/my data/train"  # Replace with the actual path

# List the contents of the directory
contents = os.listdir(directory_path)

# Print the list of contents
print(contents)
# Out:
# ['.DS_Store', 'Hand-bags', 'wallets', 'Bags', 'Balls', 'Sunglasses', 'shorts', 'Pants', 'T-shirts', 'sneakers', 'Loafers', 'Socks', 'Watches', 'Sandals']

# %%
model = keras.applications.VGG16(weights='imagenet', include_top=True)

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
#  predictions (Dense)         (None, 1000)              4097000
#
# =================================================================
# Total params: 138357544 (527.79 MB)
# Trainable params: 138357544 (527.79 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image

def load_image(path):
    img = image.load_img(path, target_size=model.input_shape[1:3])
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    return img, x

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image  # Import the image module from TensorFlow's Keras

# Define a function to load and preprocess an image
def load_image(path):
    img = image.load_img(path, target_size=(224,224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    return img, x

# Example usage of the load_image function
img, x = load_image("/content/drive/MyDrive/my data/test/fcb9e84b-a040-4871-891e-8c43ed40bc25.jpg")
print("shape of x: ", x.shape)
print("data type: ", x.dtype)
plt.imshow(img)
plt.show()
# Out:
# shape of x:  (1, 224, 224, 3)
# data type:  float32

# %%
from keras.applications.vgg16 import VGG16, decode_predictions, preprocess_input
from keras.preprocessing import image
import numpy as np

# Load the pre-trained VGG16 model
model = VGG16(weights='imagenet')

# Load and preprocess an image (replace 'path_to_image.jpg' with the actual path to your image)
img_path = '/content/drive/MyDrive/my data/test/fcb9e84b-a040-4871-891e-8c43ed40bc25.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# Make predictions using the model
predictions = model.predict(x)

# Decode the predictions to get class labels and probabilities
decoded_predictions = decode_predictions(predictions, top=5)[0]

# Print the top predicted classes and their probabilities
for label, description, score in decoded_predictions:
    print(f"{description} ({label}): {score:.2f}")
# Out:
# 1/1 [==============================] - 1s 1s/step
# trench_coat (n04479046): 0.54
# fur_coat (n03404251): 0.09
# cloak (n03045698): 0.08
# poncho (n03980874): 0.05
# velvet (n04525038): 0.03

# %%
# # forward the image through the network
# predictions = model.predict(x)

# # print out the
# for _, pred, prob in decode_predictions(predictions)[0]:
#     print("predicted %s with probability %0.3f" % (pred, prob))

# %%
# Assuming you have already made predictions using your model
for pred in predictions:
    print("Predicted values:", pred)
# Out:
# Predicted values: [1.53368892e-05 5.00101862e-07 8.71823522e-06 1.86229154e-05
#  1.18990174e-05 1.16122310e-05 1.91917643e-05 1.33185097e-06
#  8.18432000e-07 4.91998833e-07 3.84214718e-06 1.25775250e-06
#  1.68626082e-06 2.25387885e-06 1.89530283e-06 1.02327022e-06
#  1.50983271e-06 3.05531125e-06 2.45633692e-06 4.97483961e-06
#  3.13822483e-07 3.35013829e-06 3.54405415e-06 3.17766967e-06
#  4.48344645e-06 1.45854676e-06 1.08133008e-06 1.97184272e-06
#  3.12033853e-06 8.16282181e-07 1.53755434e-06 1.39812000e-05
#  1.04771589e-05 2.90807588e-06 2.05914075e-05 3.09270177e-07
#  1.48908100e-06 7.06870026e-07 3.36494759e-06 1.50908420e-06
#  4.82511905e-06 1.39821793e-06 1.14568172e-06 4.70157011e-06
#  1.71228635e-06 2.75192747e-06 2.21955383e-06 2.41420639e-06
#  1.69355656e-06 1.93982487e-06 2.84308180e-06 4.84523343e-06
#  5.00213264e-06 1.98086150e-06 2.53456119e-06 2.38573443e-06
#  1.28548845e-06 1.12144817e-05 3.12358534e-05 2.76504172e-04
#  1.77739730e-05 1.09334331e-04 1.99882197e-03 1.03023976e-05
#  1.36060851e-06 7.29011981e-06 3.08029521e-05 6.35210704e-03
#  2.51767801e-06 3.67781445e-06 1.02658332e-05 2.64380487e-05
#  3.95172356e-05 1.66054760e-05 6.03098269e-05 6.59843408e-06
#  4.03972763e-06 1.57937087e-04 3.40155862e-06 3.10223768e-05
#  8.05332093e-06 1.89109960e-06 1.07107792e-06 1.97255372e-06
#  9.64093488e-06 2.26052420e-04 2.41536145e-05 7.76591787e-06
#  4.50372090e-06 6.03880653e-06 1.46311004e-05 5.96014843e-06
#  3.53345567e-05 1.63037366e-05 3.12852671e-06 1.02522245e-05
#  1.28362149e-06 1.85437739e-06 2.73348974e-06 4.89562444e-06
#  1.35073169e-05 8.61467981e-07 8.60015916e-07 3.01162572e-06
#  1.09387356e-05 2.34609615e-06 4.16971216e-06 2.35405923e-06
#  1.38625774e-06 6.19219691e-06 2.65019407e-05 6.90515526e-06
#  1.05176132e-05 5.29200634e-07 2.25183135e-06 1.72894966e-06
#  9.36378819e-06 1.17575917e-04 2.14701663e-06 2.58660953e-06
#  4.32288789e-06 3.22444466e-05 2.19303947e-05 7.50568961e-06
#  3.09100651e-05 3.23927452e-06 1.43033658e-05 1.44477690e-05
#  3.50147056e-05 2.36866117e-06 6.73435397e-06 1.82369467e-06
#  6.25206985e-06 3.42124949e-05 2.87533885e-06 2.35987886e-06
#  1.60051832e-06 9.39211677e-05 3.22473556e-04 2.10422586e-05
#  7.49966091e-07 9.30905060e-07 2.02141322e-07 7.89372189e-06
#  1.28879913e-06 2.74413992e-07 4.25182435e-07 8.73222689e-07
#  9.44412932e-07 1.76309879e-06 1.41812802e-06 9.94199581e-07
#  6.17123351e-06 1.34228787e-06 3.81506925e-06 1.14322931e-04]

# %%
# import tensorflow as tf

# # Specify the name of the last dense layer
# layer_name = 'dense_6'  # Use the correct layer name

# # Create a feature extractor model using the specified layer name
# feat_extractor = tf.keras.models.Model(inputs=model.input, outputs=model.get_layer(layer_name).output)

# # Print the summary of the feature extractor model
# feat_extractor.summary()

# %%
# img, x = load_image("/content/drive/MyDrive/my data/test/fdbcfdcd-5deb-4a20-9aef-b708831ef774.jpg")
# feat = feat_extractor.predict(x)

# plt.figure(figsize=(16,4))
# plt.plot(feat[0])

import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model

# Load the pre-trained VGG16 model
base_model = VGG16(weights='imagenet')
# Specify the layer from which you want to extract features
layer_name = 'fc2'  # Change this to the desired layer

# Create a feature extractor model
feat_extractor = Model(inputs=base_model.input, outputs=base_model.get_layer(layer_name).output)

# Define a function to load and preprocess an image
def load_image(path):
    img = image.load_img(path, target_size=(224, 224))  # Make sure to adjust the target size
    x = image.img_to_array(img)
    x = preprocess_input(x)
    x = np.expand_dims(x, axis=0)
    return img, x

# Example usage of the load_image function
img, x = load_image("/content/drive/MyDrive/my data/test/fdbcfdcd-5deb-4a20-9aef-b708831ef774.jpg")  # Replace with the path to your image
print("shape of x: ", x.shape)
print("data type: ", x.dtype)

# Extract features from the image
features = feat_extractor.predict(x)

# Print the shape of the extracted features
print("Shape of extracted features:", features.shape)
# Out:
# shape of x:  (1, 224, 224, 3)
# data type:  float32
# 1/1 [==============================] - 1s 888ms/step
# Shape of extracted features: (1, 4096)

# %%
images_path = '/content/drive/MyDrive/my data/train'
image_extensions = ['.jpg', '.png', '.jpeg']   # case-insensitive (upper/lower doesn't matter)
max_num_images = 10000

images = [os.path.join(dp, f) for dp, dn, filenames in os.walk(images_path) for f in filenames if os.path.splitext(f)[1].lower() in image_extensions]
if max_num_images < len(images):
    images = [images[i] for i in sorted(random.sample(xrange(len(images)), max_num_images))]

print("keeping %d images to analyze" % len(images))
# Out:
# keeping 1147 images to analyze

# %%
import time

# Record the start time
tic = time.perf_counter()

features = []
for i, image_path in enumerate(images):
    if i % 500 == 0:
        toc = time.perf_counter()
        elap = toc - tic
        print("Analyzing image %d / %d. Time: %4.4f seconds." % (i, len(images), elap))
        tic = time.perf_counter()
    img, x = load_image(image_path)
    feat = feat_extractor.predict(x)[0]
    features.append(feat)

print('Finished extracting features for %d images' % len(images))

# Record the end time
toc = time.perf_counter()

# Calculate and print the total elapsed time
total_time = toc - tic
print(f'Total elapsed time: {total_time} seconds')
# Out:
# Analyzing image 0 / 1147. Time: 0.0002 seconds.
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 976ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 632ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 889ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 969ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 804ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 819ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 957ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 932ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 1s 747ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 703ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 978ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 979ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 807ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 894ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 977ms/step
# 1/1 [==============================] - 1s 632ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 990ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 633ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 715ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 995ms/step
# 1/1 [==============================] - 1s 926ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 624ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 789ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 948ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 789ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 781ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 877ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 748ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 661ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 960ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 575ms/step
# Analyzing image 500 / 1147. Time: 393.9843 seconds.
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 961ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 982ms/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 820ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 746ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 916ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 650ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 728ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 640ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 932ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 923ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 949ms/step
# 1/1 [==============================] - 1s 672ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 901ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 994ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 966ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 562ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 752ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 662ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 995ms/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 915ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 772ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 709ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 676ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 742ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 997ms/step
# 1/1 [==============================] - 1s 920ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 1s 621ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 807ms/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 785ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 648ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 891ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 564ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 998ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 650ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 722ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 957ms/step
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# Analyzing image 1000 / 1147. Time: 392.9219 seconds.
# 1/1 [==============================] - 1s 991ms/step
# 1/1 [==============================] - 1s 675ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 807ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 638ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 969ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 738ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 998ms/step
# 1/1 [==============================] - 1s 790ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 566ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 574ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 621ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 981ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 565ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 573ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 659ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 571ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 733ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 567ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 977ms/step
# 1/1 [==============================] - 1s 570ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 582ms/step
# Finished extracting features for 1147 images
# Total elapsed time: 118.01962063499741 seconds

# %%
from sklearn.decomposition import PCA

# Define the number of components you want to use (less than or equal to 6)
n_components = 6

# Create a PCA model
pca = PCA(n_components=n_components)

# Fit the PCA model to your features
pca.fit(features)  # Replace 'features' with your actual feature data
# Out:
# PCA(n_components=6)

# %%
pca_features = pca.transform(features)

# %%
import random

# grab a random query image
query_image_idx = int(len(images) * random.random())

# let's display the image
img = image.load_img(images[query_image_idx])
plt.imshow(img)

# %%
from scipy.spatial import distance

similar_idx = [ distance.cosine(pca_features[query_image_idx], feat) for feat in pca_features ]

# %%
idx_closest = sorted(range(len(similar_idx)), key=lambda k: similar_idx[k])[1:6]

# %%
# load all the similarity results as thumbnails of height 100
thumbs = []
for idx in idx_closest:
    img = image.load_img(images[idx])
    img = img.resize((int(img.width * 100 / img.height), 100))
    thumbs.append(img)

# concatenate the images into a single image
concat_image = np.concatenate([np.asarray(t) for t in thumbs], axis=1)

# show the image
plt.figure(figsize = (16,12))
plt.imshow(concat_image)

# %%
def get_closest_images(query_image_idx, num_results=5):
    distances = [ distance.cosine(pca_features[query_image_idx], feat) for feat in pca_features ]
    idx_closest = sorted(range(len(distances)), key=lambda k: distances[k])[1:num_results+1]
    return idx_closest

def get_concatenated_images(indexes, thumb_height):
    thumbs = []
    for idx in indexes:
        img = image.load_img(images[idx])
        img = img.resize((int(img.width * thumb_height / img.height), thumb_height))
        thumbs.append(img)
    concat_image = np.concatenate([np.asarray(t) for t in thumbs], axis=1)
    return concat_image

# %%
# do a query on a random image
query_image_idx = int(len(images) * random.random())
idx_closest = get_closest_images(query_image_idx)
query_image = get_concatenated_images([query_image_idx], 300)
results_image = get_concatenated_images(idx_closest, 200)

# display the query image
plt.figure(figsize = (5,5))
plt.imshow(query_image)
plt.title("query image (%d)" % query_image_idx)
# Out:
# Text(0.5, 1.0, 'query image (224)')

# %%
# display the resulting images
plt.figure(figsize = (16,12))
plt.imshow(results_image)
plt.title("result images")
# Out:
# Text(0.5, 1.0, 'result images')

# %%
# do a query on a random image
query_image_idx = int(len(images) * random.random())
idx_closest = get_closest_images(query_image_idx)
query_image = get_concatenated_images([query_image_idx], 300)
results_image = get_concatenated_images(idx_closest, 200)

# display the query image
plt.figure(figsize = (5,5))
plt.imshow(query_image)
plt.title("query image (%d)" % query_image_idx)
# Out:
# Text(0.5, 1.0, 'query image (866)')

# %%
# display the resulting images
plt.figure(figsize = (16,12))
plt.imshow(results_image)
plt.title("result images")
# Out:
# Text(0.5, 1.0, 'result images')

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# load image and extract features
new_image, x = load_image("/content/drive/MyDrive/my data/test/fa53d8bd-0c11-4849-bd90-0eb6737f63a2.jpg")
new_features = feat_extractor.predict(x)

# project it into pca space
new_pca_features = pca.transform(new_features)[0]

# calculate its distance to all the other images pca feature vectors
distances = [ distance.cosine(new_pca_features, feat) for feat in pca_features ]
idx_closest = sorted(range(len(distances)), key=lambda k: distances[k])[0:5]  # grab first 5
results_image = get_concatenated_images(idx_closest, 200)

# display the results
plt.figure(figsize = (5,5))
plt.imshow(new_image)
plt.title("query image")

# display the resulting images
plt.figure(figsize = (16,12))
plt.imshow(results_image)
plt.title("result images")
# Out:
# Mounted at /content/drive
# 1/1 [==============================] - 1s 598ms/step
# Text(0.5, 1.0, 'result images')

# %%
import pickle

# Specify the complete file path, including the filename
file_path = '/content/drive/MyDrive/my data.p'

# Serialize and save the data to the specified file
pickle.dump([images, pca_features, pca], open(file_path, 'wb'))

# %%
# # Save the model to a file using the native Keras format
# model.save("/content/drive/MyDrive/my_data/my_model.keras")

# %%
# Save the model to a file
#model.save("/content/drive/MyDrive/my_data/my_model.h5")

# %%
# !pip install streamlit -q

# %%
# !wget -q -O - ipv4.icanhazip.com
# Out:
# 34.127.15.193

# %%
from scipy.spatial import distance

# %%
# %%writefile app.py

import streamlit as st
import os
import keras
import numpy as np
from keras.preprocessing import image
from keras.applications.vgg16 import VGG16, decode_predictions, preprocess_input
from PIL import Image
import pickle
from scipy.spatial import distance

# Load the pre-trained VGG16 model
model = VGG16(weights='imagenet')

# Load the saved PCA features and images list
file_path = '/content/drive/MyDrive/my data.p'
images, pca_features, pca = pickle.load(open(file_path, 'rb'))

# Define the feature extractor using the VGG16 model
base_model = VGG16(weights='imagenet')
layer_name = 'fc2'
feat_extractor = keras.models.Model(inputs=base_model.input, outputs=base_model.get_layer(layer_name).output)

# Function to load and preprocess an image
def load_image(path):
    img = image.load_img(path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = preprocess_input(x)
    x = np.expand_dims(x, axis=0)
    return x

# Streamlit UI
st.title("Image Classifier with Streamlit")

# Upload an image
uploaded_image = st.file_uploader("Upload an image...", type=["jpg", "png", "jpeg"])

if uploaded_image is not None:
    # Display the uploaded image
    st.image(uploaded_image, caption="Uploaded Image", use_column_width=True)

    # Perform predictions on the uploaded image
    img = Image.open(uploaded_image)
    img_path = "temp_image.jpg"
    img.save(img_path)

    # Load and preprocess the uploaded image
    x = load_image(img_path)

    # Make predictions using the model
    predictions = model.predict(x)

    # Decode the predictions to get class labels and probabilities
    decoded_predictions = decode_predictions(predictions, top=5)[0]

    st.subheader("Top Predicted Classes:")
    for label, description, score in decoded_predictions:
        st.write(f"{description} ({label}): {score:.2f}")

    # Calculate PCA features for the uploaded image
    img_features = feat_extractor.predict(x)[0]
    img_pca_features = pca.transform([img_features])[0]

    # Calculate distances to all other images
    distances = [distance.cosine(img_pca_features, feat) for feat in pca_features]
    idx_closest = sorted(range(len(distances)), key=lambda k: distances[k])[0:5]

    st.subheader("Most Similar Images:")
    for idx in idx_closest:
        similar_img = Image.open(images[idx])
        st.image(similar_img, caption=f"Similar Image {idx}", use_column_width=True)

# Add a sidebar to display additional information or options if needed
# st.sidebar.title("Options")
# st.sidebar.write("You can add sidebar options here.")

# %%
# %%writefile app.py
# import streamlit as st
# import os
# import keras
# import numpy as np
# from keras.preprocessing import image
# from keras.applications.vgg16 import VGG16, decode_predictions, preprocess_input
# from PIL import Image
# import pickle
# from scipy.spatial import distance  # Add this import statement




# # Load the pre-trained VGG16 model
# model = VGG16(weights='imagenet')

# # Load the saved PCA features and images list
# file_path = '/content/drive/MyDrive/my data.p'
# images, pca_features, pca = pickle.load(open(file_path, 'rb'))

# # Define the feature extractor using the VGG16 model
# base_model = VGG16(weights='imagenet')
# layer_name = 'fc2'
# feat_extractor = keras.models.Model(inputs=base_model.input, outputs=base_model.get_layer(layer_name).output)

# # Function to load and preprocess an image
# def load_image(path):
#     img = image.load_img(path, target_size=(224, 224))
#     x = image.img_to_array(img)
#     x = preprocess_input(x)
#     x = np.expand_dims(x, axis=0)
#     return x

# # Streamlit UI
# st.title("Image Classifier with Streamlit")

# # Upload an image
# uploaded_image = st.file_uploader("Upload an image...", type=["jpg", "png", "jpeg"])

# if uploaded_image is not None:
#     # Display the uploaded image
#     st.image(uploaded_image, caption="Uploaded Image", use_column_width=True)

#     # Perform predictions on the uploaded image
#     img = Image.open(uploaded_image)
#     img_path = "temp_image.jpg"
#     img.save(img_path)

#     # Load and preprocess the uploaded image
#     x = load_image(img_path)

#     # Make predictions using the model
#     predictions = model.predict(x)

#     # Decode the predictions to get class labels and probabilities
#     decoded_predictions = decode_predictions(predictions, top=5)[0]

#     st.subheader("Top Predicted Classes:")
#     for label, description, score in decoded_predictions:
#         st.write(f"{description} ({label}): {score:.2f}")

#     # Calculate PCA features for the uploaded image
#     img_features = feat_extractor.predict(x)[0]
#     img_pca_features = pca.transform([img_features])[0]

#     # Calculate distances to all other images
#     distances = [distance.cosine(img_pca_features, feat) for feat in pca_features]
#     idx_closest = sorted(range(len(distances)), key=lambda k: distances[k])[0:5]

#     st.subheader("Most Similar Images:")
#     for idx in idx_closest:
#         similar_img = Image.open(images[idx])
#         st.image(similar_img, caption=f"Similar Image {idx}", use_column_width=True)

# # Add a sidebar to display additional information or options if needed
# # st.sidebar.title("Options")
# # st.sidebar.write("You can add sidebar options here.")

# %%
# !streamlit run app.py & npx localtunnel --port 8501
# Out:
# [..................] / rollbackFailedOptional: verb npm-session 96fbb470bde2ff6
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to False.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.127.15.193:8501
#
# npx: installed 22 in 2.563s
# your url is: https://thirty-clocks-write.loca.lt
#   Stopping...
# ^C
